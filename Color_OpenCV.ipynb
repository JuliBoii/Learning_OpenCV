# %% [markdown]
# # Color Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cimg = plt.imread(r'/Users/angelito/Documents/python_projects/Learn/Learning_OpenCV/imgs/tulips.jpg')

# %%
plt.imshow(cimg)

# %%
cimg.shape
# Out:
# (638, 640, 3)

# %%
type(cimg)
# Out:
# numpy.ndarray

# %%
cimg.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# # OpenCV reads as BGR

# %%
cimg = cv2.imread(r'/Users/angelito/Documents/python_projects/Learn/Learning_OpenCV/imgs/tulips.jpg')
cimg = cimg[:,:,::-1]
R = cimg[:,:,0]
G = cimg[:,:,1]
B = cimg[:,:,2]

# %%
plt.figure(1)

plt.subplot(231)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(233)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(234)
plt.imshow(R,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Red')

plt.subplot(235)
plt.imshow(G,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Green')

plt.subplot(236)
plt.imshow(B,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Blue')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
R[100:400,100:400] = 100
G[100:400,100:400] = 50
B[100:400,100:400] = 70
cimg[:,:,0] = R
cimg[:,:,1] = G
cimg[:,:,2] = B

plt.figure(1)

plt.subplot(231)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(232)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(233)
plt.imshow(cimg)
plt.xticks([])
plt.yticks([])

plt.subplot(234)
plt.imshow(R,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Red')

plt.subplot(235)
plt.imshow(G,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Green')

plt.subplot(236)
plt.imshow(B,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Blue')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
