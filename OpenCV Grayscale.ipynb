# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Grayscale Images in OpenCV

# %%
img = cv2.imread(r'/Users/angelito/Documents/python_projects/Learn/Learning_OpenCV/imgs/albert-einstein_gray.jpg', cv2.IMREAD_GRAYSCALE)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (949, 728)

# %%
plt.imshow(img,cmap='gray')

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[500:700,500:600] = 255

# %%
cv2.imshow('Gray',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('/Users/angelito/Documents/python_projects/Learn/Learning_OpenCV/imgs/albert-einstein_gray_opencv.jpg', img)
# Out:
# True
